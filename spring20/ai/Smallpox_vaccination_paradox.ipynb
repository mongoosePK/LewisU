# %% [markdown]
# # <font color="olivedrab"> \*\*Smallpox Paradox\*\*</font>

# %% [markdown]
# **This notebook follows the example from "The Book Of Why" (Pearl, 2018) chapter 1 page 050.**

# %%
from IPython.display import display, Math, Latex,HTML

import pyAgrum as gum
import pyAgrum.lib.notebook as gnb
import pyAgrum.causal as csl
import pyAgrum.causal.notebook as cslnb
import os

# %% [markdown]
# >"When the smallpox vaccine was first introduced. Unexpectedly, data showed that more people died from smallpox inoculations than from smallpox itself. Naturally, some people used this information to argue that inoculation should be banned, when in fact it was saving lives by eradicating smallpox. Let’s look at some fictitious data to illustrate the effect and settle the dispute. We have a population of one million children." chapter1, page 50.

# %% [markdown]
# #### **We create the causal diagram:**
# * The vaccination rate is set to 0.99.
#     * You have a 0.01 probability of developing a reaction to the vaccine.
#     * You have a 0.02 probability of contracting smallpox if you don't get vaccinated.
#         * You have a 0.01 probability of dying from a reaction to the vaccine.
#         * You have a 0.2 probability of dying from smallpox.
# The corresponding causal diagram is the following:

# %%
sp = gum.fastBN("vaccination->reaction->death<-smallPox<-vaccination")
sp
# Out:
# (gum::BayesNet<double>@0x1a49260) BN{nodes: 4, arcs: 4, domainSize: 16, dim: 18}

# %%
# filling the CPTs

# This function adds a uniform noise to a CPT
def smallPertubation(cpt,epsilon=0.0001):
    cpt.fillWith(cpt.translate(epsilon).normalizeAsCPT())


# Fictitious data
sp.cpt("vaccination")[:] = [0.01, 0.99]
sp.cpt("reaction")[0,:] = [1,0] # sp=0
sp.cpt("reaction")[1,:] = [0.99, 0.01] # sp=1
sp.cpt("smallPox")[0,:] = [0.98, 0.02] # sp=0
sp.cpt("smallPox")[1,:] = [1, 0] # sp=1

sp.cpt("death")[0,0,:] = [1, 0] # r=0,s=0
sp.cpt("death")[1,0,:] = [0.8, 0.2] # r=0,s=1
sp.cpt("death")[0,1,:] = [0.99, 0.01] # r=1,s=0
# This case is not possible
sp.cpt("death")[1,1,:] = [0.5, 0.5] # r=1,s=1


# We add a uniform noise to the CPTs
epsilon=0.000000001
smallPertubation(sp.cpt("reaction"), epsilon)
smallPertubation(sp.cpt("smallPox"), epsilon)
smallPertubation(sp.cpt("death"), epsilon)

# %%
gnb.sideBySide(sp,sp.cpt("vaccination"),
               sp.cpt("reaction"),
               captions=["the BN","the marginal for $vaccination$","the CPT for $reaction$"])
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="192pt" height="188pt" viewBox="0.00 0.00 192.19 188.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 184)">
# <title>G</title>
# <!-- vaccination -->
# <g id="node1" class="node">
# <title>vaccination</title>
# <g id="a_node1"><a xlink:title="(0) vaccination">
# <ellipse fill="#404040" stroke="#000000" cx="88.9965" cy="-162" rx="51.1914" ry="18"/>
# <text text-anchor="middle" x="88.9965" y="-158.3" font-family="Times,serif" font-size="14.00" fill="#ffffff">vaccination</text>
# </a>
# </g>
# </g>
# <!-- reaction -->
# <g id="node2" class="node">
# <title>reaction</title>
# <g id="a_node2"><a xlink:title="(1) reaction">
# <ellipse fill="#404040" stroke="#000000" cx="38.9965" cy="-90" rx="38.9931" ry="18"/>
# <text text-anchor="middle" x="38.9965" y="-86.3" font-family="Times,serif" font-size="14.00" fill="#ffffff">reaction</text>
# </a>
# </g>
# </g>
# <!-- vaccination&#45;&gt;reaction -->
# <g id="edge1" class="edge">
# <title>vaccination-&gt;reaction</title>
# <g id="a_edge1"><a xlink:title="(0, 1) : ">
# <path fill="none" stroke="#4a4a4a" d="M76.637,-144.2022C70.6589,-135.5938 63.3723,-125.1011 56.8082,-115.6488"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="59.6202,-113.5619 51.0414,-107.3446 53.8706,-117.5547 59.6202,-113.5619"/>
# </a>
# </g>
# </g>
# <!-- smallPox -->
# <g id="node4" class="node">
# <title>smallPox</title>
# <g id="a_node4"><a xlink:title="(3) smallPox">
# <ellipse fill="#404040" stroke="#000000" cx="139.9965" cy="-90" rx="44.393" ry="18"/>
# <text text-anchor="middle" x="139.9965" y="-86.3" font-family="Times,serif" font-size="14.00" fill="#ffffff">smallPox</text>
# </a>
# </g>
# </g>
# <!-- vaccination&#45;&gt;smallPox -->
# <g id="edge3" class="edge">
# <title>vaccination-&gt;smallPox</title>
# <g id="a_edge3"><a xlink:title="(0, 3) : ">
# <path fill="none" stroke="#4a4a4a" d="M101.6033,-144.2022C107.7009,-135.5938 115.1333,-125.1011 121.8286,-115.6488"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="124.7867,-117.5279 127.7108,-107.3446 119.0745,-113.4818 124.7867,-117.5279"/>
# </a>
# </g>
# </g>
# <!-- death -->
# <g id="node3" class="node">
# <title>death</title>
# <g id="a_node3"><a xlink:title="(2) death">
# <ellipse fill="#404040" stroke="#000000" cx="88.9965" cy="-18" rx="29.795" ry="18"/>
# <text text-anchor="middle" x="88.9965" y="-14.3" font-family="Times,serif" font-size="14.00" fill="#ffffff">death</text>
# </a>
# </g>
# </g>
# <!-- reaction&#45;&gt;death -->
# <g id="edge2" class="edge">
# <title>reaction-&gt;death</title>
# <g id="a_edge2"><a xlink:title="(1, 2) : ">
# <path fill="none" stroke="#4a4a4a" d="M51.1001,-72.5708C57.2074,-63.7763 64.7287,-52.9457 71.4565,-43.2577"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="74.5195,-44.983 77.3487,-34.7729 68.7699,-40.9902 74.5195,-44.983"/>
# </a>
# </g>
# </g>
# <!-- smallPox&#45;&gt;death -->
# <g id="edge4" class="edge">
# <title>smallPox-&gt;death</title>
# <g id="a_edge4"><a xlink:title="(3, 2) : ">
# <path fill="none" stroke="#4a4a4a" d="M127.6509,-72.5708C121.3579,-63.6866 113.593,-52.7245 106.6776,-42.9615"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="109.5137,-40.9101 100.8774,-34.7729 103.8015,-44.9563 109.5137,-40.9101"/>
# </a>
# </g>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'><th colspan='2'><center>vaccination</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>1</center></th></tr>
# <tr><td style='color:black;background-color:#fd8064;text-align:right;'>0.0100</td><td style='color:black;background-color:#80fd64;text-align:right;'>0.9900</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><table style="border:1px solid black;">
# <tr><th colspan='1'></th><th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>reaction</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>vaccination</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>1</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#7ffe64;text-align:right;'>1.0000</td><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#80fd64;text-align:right;'>0.9900</td><td style='color:black;background-color:#fd8064;text-align:right;'>0.0100</td></tr>
# </table></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>the BN</small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>the marginal for $vaccination$</small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>the CPT for $reaction$</small></div></td></tr></table>

# %%
 gnb.sideBySide(sp.cpt("smallPox"),
                sp.cpt("death"),
                captions=["the CPT for $smallPox$","the CPT for $death$"])
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><table style="border:1px solid black;">
# <tr><th colspan='1'></th><th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>smallPox</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>vaccination</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>1</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#81fc64;text-align:right;'>0.9800</td><td style='color:black;background-color:#fc8164;text-align:right;'>0.0200</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#7ffe64;text-align:right;'>1.0000</td><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0000</td></tr>
# </table></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><table style="border:1px solid black;">
# <tr><th colspan='2'></th><th colspan='2' style='border:1px solid black;color:black;background-color:#808080;'><center>death</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#808080'><center>smallPox</center></th><th style='border:1px solid black;color:black;background-color:#808080'><center>reaction</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>1</center></th></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'><center>0</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#7ffe64;text-align:right;'>1.0000</td><td style='color:black;background-color:#fe7f64;text-align:right;'>0.0000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#80fd64;text-align:right;'>0.9900</td><td style='color:black;background-color:#fd8064;text-align:right;'>0.0100</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB;' rowspan = '2'><center>1</center></th><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>0</center></th><td style='color:black;background-color:#98e564;text-align:right;'>0.8000</td><td style='color:black;background-color:#e59864;text-align:right;'>0.2000</td></tr>
# <tr><th style='border:1px solid black;color:black;background-color:#BBBBBB'><center>1</center></th><td style='color:black;background-color:#bfbf64;text-align:right;'>0.5000</td><td style='color:black;background-color:#bfbf64;text-align:right;'>0.5000</td></tr>
# </table></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>the CPT for $smallPox$</small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>the CPT for $death$</small></div></td></tr></table>

# %% [markdown]
# ### **We Have That**
# $$P(reaction = 1 \mid vaccination = 1 ) < P(smallPox = 1 \mid vaccination = 0 )$$
# $$P(death = 1 \mid reaction = 1) < P(death = 1 \mid smallPox = 1)$$
# >We know that the probability of developing a reaction to the vaccine is lower than the probability of contracting smallpox if one does not vaccinate. We also know that the probability of dying from smallpox is greater than the probability of dying from a reaction to the vaccine. (smallpox is more threatening to one's life than a reaction to the vaccine)

# %%
def getAliveObservedProba(sp,evs):
    evs0=dict(evs)
    evs1=dict(evs)
    evs0["vaccination"]=0
    evs1["vaccination"]=1
    
    return gum.Potential().add(sp.variableFromName("vaccination")).fillWith([
            gum.getPosterior(sp,target="death",evs=evs0)[1],
            gum.getPosterior(sp,target="death",evs=evs1)[1]
        ])

gnb.sideBySide(getAliveObservedProba(sp,{}),
               captions=["$P(death = 1 \mid vaccination )$<br/>$P(death = 1 \mid vaacination = 0) > P(death = 1 \mid vaacination = 1)$"])
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'><th colspan='2'><center>vaccination</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>1</center></th></tr>
# <tr><td style='text-align:right;'>0.0040</td><td style='text-align:right;'>0.0001</td></tr>
# </table></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>$P(death = 1 \mid vaccination )$<br/>$P(death = 1 \mid vaacination = 0) > P(death = 1 \mid vaacination = 1)$</small></div></td></tr></table>

# %% [markdown]
# Based on this information, we can say that vaccination is a good choice. However, more children die from vaccination than from smallpox itself according to the data:
#
# * Number of people dying from a reaction:
# $$P(vaccination=1)×P(reaction=1∣vaccination=1)×P(death=1∣reaction=1)×1000000=99$$
# * Number of people dying from smallpox:
# $$P(vaccination=0)×P(smallPox=1∣vaccination=0)×P(death=1∣smallPox=1)×1000000=40$$
# **In total if the vaccination rate is set to 99% we have 139 deaths.**
# ### When we began, the vaccination rate was 99 percent. We now ask the counterfactual question “What if we had set the vaccination rate to zero?”

# %%
# Counterfactual world where the vaccination rate is set to 0
spCounterfactual = gum.BayesNet(sp)
spCounterfactual.cpt("vaccination")[:] = [1, 0]

# %%
gnb.sideBySide(gnb.getInference(sp),
               gnb.getInference(spCounterfactual),
               captions=["<b>factual world:</b> the vaccination rate is set to 0.99 <br> lower risk of contracting smallpox, higher risk of developing a reaction, lower probability of death","<b>counterfactual world:</b> the vaccination rate is set to 0 <br> higher risk of contracting smallpox, lower risk of developing a reaction, higher probability of death"])
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="228pt" height="259pt" viewBox="0.00 0.00 228.00 259.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 255)">
# <title>structs</title>
# <text text-anchor="middle" x="110" y="-7.8" font-family="Times,serif" font-size="14.00" fill="#4a4a4a">Inference in   0.42ms</text>
# <!-- vaccination -->
# <g id="node1" class="node">
# <title>vaccination</title>
# <polygon fill="#ffffff" stroke="#000000" points="160,-251 59,-251 59,-199 160,-199 160,-251"/>
# <svg viewBox="0 0 132.1625 66.4355" width="101px" height="52px" preserveAspectRatio="xMinYMin meet" x="59" y="-251"> <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="M 0 66.4355  L 132.1625 66.4355  L 132.1625 0  L 0 0  z " style="fill:none;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="M 16.9625 59.3355  L 128.5625 59.3355  L 128.5625 32.1555  L 16.9625 32.1555  z " style="fill:none;"/>
#    </g>
#    <g id="patch_3">
#     <path clip-path="url(#p13b19d74bf)" d="M 16.9625 59.3355  L 127.4465 59.3355  L 127.4465 47.2555  L 16.9625 47.2555  z " style="fill:#8fbc8f;"/>
#    </g>
#    <g id="patch_4">
#     <path clip-path="url(#p13b19d74bf)" d="M 16.9625 44.2355  L 18.0785 44.2355  L 18.0785 32.1555  L 16.9625 32.1555  z " style="fill:#8fbc8f;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_1">
#       <path clip-path="url(#p13b19d74bf)" d="M 16.9625 59.3355  L 16.9625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_2">
#       <defs>
#        <path d="M 0 0  L 0 3.5  " id="m354f9d1379" style="stroke:#000000;stroke-width:0.8;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="16.9625" xlink:href="#m354f9d1379" y="59.3355"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_3">
#       <path clip-path="url(#p13b19d74bf)" d="M 72.7625 59.3355  L 72.7625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_4">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="72.7625" xlink:href="#m354f9d1379" y="59.3355"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_5">
#       <path clip-path="url(#p13b19d74bf)" d="M 128.5625 59.3355  L 128.5625 32.1555  " style="fill:none;stroke:#b0b0b0;stroke-linecap:square;stroke-width:0.8;"/>
#      </g>
#      <g id="line2d_6">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="128.5625" xlink:href="#m354f9d1379" y="59.3355"/>
#       </g>
#      </g>
#     </g>
#    </g>
#    <g id="matplotlib.axis_2">
#     <g id="ytick_1">
#      <g id="line2d_7">
#       <defs>
#        <path d="M 0 0  L -3.5 0  " id="mb2b863e550" style="stroke:#000000;stroke-width:0.8;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="16.9625" xlink:href="#mb2b863e550" y="53.2955"/>
#       </g>
#      </g>
#      <g id="text_1">
#       <!-- 1 -->
#       <defs>
#        <path d="M 12.40625 8.296875  L 28.515625 8.296875  L 28.515625 63.921875  L 10.984375 60.40625  L 10.984375 69.390625  L 28.421875 72.90625  L 38.28125 72.90625  L 38.28125 8.296875  L 54.390625 8.296875  L 54.390625 0  L 12.40625 0  z " id="DejaVuSans-49"/>
#       </defs>
#       <g transform="translate(3.6 57.094719)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-49"/>
#       </g>
#      </g>
#     </g>
#     <g id="ytick_2">
#      <g id="line2d_8">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.8;" x="16.9625" xlink:href="#mb2b863e550" y="38.1955"/>
#       </g>
#      </g>
#      <g id="text_2">
#       <!-- 0 -->
#       <defs>
#        <path d="M 31.78125 66.40625  Q 24.171875 66.40625 20.328125 58.90625  Q 16.5 51.421875 16.5 36.375  Q 16.5 21.390625 20.328125 13.890625  Q 24.171875 6.390625 31.78125 6.390625  Q 39.453125 6.390625 43.28125 13.890625  Q 47.125 21.390625 47.125 36.375  Q 47.125 51.421875 43.28125 58.90625  Q 39.453125 66.40625 31.78125 66.40625  z M 31.78125 74.21875  Q 44.046875 74.21875 50.515625 64.515625  Q 56.984375 54.828125 56.984375 36.375  Q 56.984375 17.96875 50.515625 8.265625  Q 44.046875 -1.421875 31.78125 -1.421875  Q 19.53125 -1.421875 13.0625 8.265625  Q 6.59375 17.96875 6.59375 36.375  Q 6.59375 54.828125 13.0625 64.515625  Q 19.53125 74.21875 31.78125 74.21875  z " id="DejaVuSans-48"/>
#       </defs>
#       <g transform="translate(3.6 41.994719)scale(0.1 -0.1)">
#        <use xlink:href="#DejaVuSans-48"/>
#       </g>
#      </g>
#     </g>
#    </g>
#    <g id="patch_5">
#     <path d="M 16.9625 59.3355  L 16.9625 32.1555  " style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;stroke-width:0.8;"/>
#    </g>
#    <g id="patch_6">
#     <path d="M 128.5625 59.3355  L 128.5625 32.1555  " style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;stroke-width:0.8;"/>
#    </g>
#    <g id="patch_7">
#     <path d="M 16.9625 59.3355  L 128.5625 59.3355  " style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;stroke-width:0.8;"/>
#    </g>
#    <g id="patch_8">
#     <path d="M 16.9625 32.1555  L 128.5625 32.1555  " style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;stroke-width:0.8;"/>
#    </g>
#    <g id="text_3">
#     <!-- 99.00% -->
#     <defs>
#      <path d="M 10.984375 1.515625  L 10.984375 10.5  Q 14.703125 8.734375 18.5 7.8125  Q 22.3125 6.890625 25.984375 6.890625  Q 35.75 6.890625 40.890625 13.453125  Q 46.046875 20.015625 46.78125 33.40625  Q 43.953125 29.203125 39.59375 26.953125  Q 35.25 24.703125 29.984375 24.703125  Q 19.046875 24.703125 12.671875 31.3125  Q 6.296875 37.9375 6.296875 49.421875  Q 6.296875 60.640625 12.9375 67.421875  Q 19.578125 74.21875 30.609375 74.21875  Q 43.265625 74.21875 49.921875 64.515625  Q 56.59375 54.828125 56.59375 36.375  Q 56.59375 19.140625 48.40625 8.859375  Q 40.234375 -1.421875 26.421875 -1.421875  Q 22.703125 -1.421875 18.890625 -0.6875  Q 15.09375 0.046875 10.984375 1.515625  z M 30.609375 32.421875  Q 37.25 32.421875 41.125 36.953125  Q 45.015625 41.5 45.015625 49.421875  Q 45.015625 57.28125 41.125 61.84375  Q 37.25 66.40625 30.609375 66.40625  Q 23.96875 66.40625 20.09375 61.84375  Q 16.21875 57.28125 16.21875 49.421875  Q 16.21875 41.5 20.09375 36.953125  Q 23.96875 32.421875 30.609375 32.421875  z " id="DejaVuSans-57"/>
#      <path d="M 10.6875 12.40625  L 21 12.40625  L 21 0  L 10.6875 0  z " id="DejaVuSans-46"/>
#      <path d="M 72.703125 32.078125  Q 68.453125 32.078125 66.03125 28.46875  Q 63.625 24.859375 63.625 18.40625  Q 63.625 12.0625 66.03125 8.421875  Q 68.453125 4.78125 72.703125 4.78125  Q 76.859375 4.78125 79.265625 8.421875  Q 81.6875 12.0625 81.6875 18.40625  Q 81.6875 24.8125 79.265625 28.4375  Q 76.859375 32.078125 72.703125 32.078125  z M 72.703125 38.28125  Q 80.421875 38.28125 84.953125 32.90625  Q 89.5 27.546875 89.5 18.40625  Q 89.5 9.28125 84.9375 3.921875  Q 80.375 -1.421875 72.703125 -1.421875  Q 64.890625 -1.421875 60.34375 3.921875  Q 55.8125 9.28125 55.8125 18.40625  Q 55.8125 27.59375 60.375 32.9375  Q 64.9375 38.28125 72.703125 38.28125  z M 22.3125 68.015625  Q 18.109375 68.015625 15.6875 64.375  Q 13.28125 60.75 13.28125 54.390625  Q 13.28125 47.953125 15.671875 44.328125  Q 18.0625 40.71875 22.3125 40.71875  Q 26.5625 40.71875 28.96875 44.328125  Q 31.390625 47.953125 31.390625 54.390625  Q 31.390625 60.6875 28.953125 64.34375  Q 26.515625 68.015625 22.3125 68.015625  z M 66.40625 74.21875  L 74.21875 74.21875  L 28.609375 -1.421875  L 20.796875 -1.421875  z M 22.3125 74.21875  Q 30.03125 74.21875 34.609375 68.875  Q 39.203125 63.53125 39.203125 54.390625  Q 39.203125 45.171875 34.640625 39.84375  Q 30.078125 34.515625 22.3125 34.515625  Q 14.546875 34.515625 10.03125 3

# %% [markdown]
# The probability of death in the counterfactual world is higher.
#
# * Number of deaths in this case:
# $$P(vaccination=0)×P(smallPox=1∣vaccination=0)×P(death=1∣smallPox=1)×1000000=4000$$
# ## In total, if the vaccination rate is set to 0%, we have 4000 deaths, compared to 139 deaths if the vaccination rate is set to 99%. Vaccination is definitely a good choice !
# >More people died from a reaction than from smallpox itself because with a vaccination rate of 0.99% the probability of developing a reaction was much higher than the probability of contracting smallpox (almost null) (since 99% of the population got vaccinated  ⟹  99% of the population had a 0.001 probability of developing a reaction, while only 1% of the population had a 0.2 percent probability of contracting smallpox) that's why we saw that the effect of a reaction on death was greater than the effect of smallpox.(we recorded the effect of a reaction to the vaccine on a much greater population)
#
# **Causal impact of reaction/vaccination on death :**
# Corresponds to the former results

# %%
spModele = csl.CausalModel(sp)
cslnb.showCausalImpact(spModele,on="death",doing="reaction", values={"reaction":1})
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="192pt" height="188pt" viewBox="0.00 0.00 192.19 188.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 184)">
# <title>G</title>
# <!-- vaccination -->
# <g id="node1" class="node">
# <title>vaccination</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="88.9965" cy="-162" rx="51.1914" ry="18"/>
# <text text-anchor="middle" x="88.9965" y="-158.3" font-family="Times,serif" font-size="14.00" fill="#ffffff">vaccination</text>
# </g>
# <!-- reaction -->
# <g id="node2" class="node">
# <title>reaction</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="38.9965" cy="-90" rx="38.9931" ry="18"/>
# <text text-anchor="middle" x="38.9965" y="-86.3" font-family="Times,serif" font-size="14.00" fill="#ffffff">reaction</text>
# </g>
# <!-- vaccination&#45;&gt;reaction -->
# <g id="edge1" class="edge">
# <title>vaccination-&gt;reaction</title>
# <path fill="none" stroke="#4a4a4a" d="M75.8156,-144.7726C69.8376,-136.1642 62.5509,-125.6715 55.9868,-116.2192"/>
# <path fill="none" stroke="#4a4a4a" d="M77.4584,-143.6318C71.4803,-135.0234 64.1936,-124.5307 57.6296,-115.0784"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="59.6202,-113.5619 51.0414,-107.3446 53.8706,-117.5547 59.6202,-113.5619"/>
# </g>
# <!-- smallPox -->
# <g id="node4" class="node">
# <title>smallPox</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="139.9965" cy="-90" rx="44.393" ry="18"/>
# <text text-anchor="middle" x="139.9965" y="-86.3" font-family="Times,serif" font-size="14.00" fill="#ffffff">smallPox</text>
# </g>
# <!-- vaccination&#45;&gt;smallPox -->
# <g id="edge3" class="edge">
# <title>vaccination-&gt;smallPox</title>
# <path fill="none" stroke="#4a4a4a" d="M100.7873,-143.6242C106.8849,-135.0158 114.3173,-124.523 121.0126,-115.0708"/>
# <path fill="none" stroke="#4a4a4a" d="M102.4193,-144.7803C108.5169,-136.1719 115.9493,-125.6791 122.6447,-116.2268"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="124.7867,-117.5279 127.7108,-107.3446 119.0745,-113.4818 124.7867,-117.5279"/>
# </g>
# <!-- death -->
# <g id="node3" class="node">
# <title>death</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="88.9965" cy="-18" rx="29.795" ry="18"/>
# <text text-anchor="middle" x="88.9965" y="-14.3" font-family="Times,serif" font-size="14.00" fill="#ffffff">death</text>
# </g>
# <!-- reaction&#45;&gt;death -->
# <g id="edge2" class="edge">
# <title>reaction-&gt;death</title>
# <path fill="none" stroke="#4a4a4a" d="M50.2788,-72.0004C56.3861,-63.2059 63.9073,-52.3753 70.6351,-42.6873"/>
# <path fill="none" stroke="#4a4a4a" d="M51.9215,-73.1412C58.0288,-64.3467 65.5501,-53.5161 72.2779,-43.8281"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="74.5195,-44.983 77.3487,-34.7729 68.7699,-40.9902 74.5195,-44.983"/>
# </g>
# <!-- smallPox&#45;&gt;death -->
# <g id="edge4" class="edge">
# <title>smallPox-&gt;death</title>
# <path fill="none" stroke="#4a4a4a" d="M126.8348,-73.1488C120.5418,-64.2646 112.777,-53.3025 105.8615,-43.5395"/>
# <path fill="none" stroke="#4a4a4a" d="M128.4669,-71.9928C122.1739,-63.1086 114.4091,-52.1464 107.4936,-42.3834"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="109.5137,-40.9101 100.8774,-34.7729 103.8015,-44.9563 109.5137,-40.9101"/>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style="">$$\begin{equation}P( death \mid \hookrightarrow\mkern-6.5mureaction) = \sum_{vaccination}{P\left(death\mid reaction,vaccination\right) \cdot P\left(vaccination\right)}\end{equation}$$</div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'><th colspan='2'><center>death</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>1</center></th></tr>
# <tr><td style='color:black;background-color:#80fd64;text-align:right;'>0.9899</td><td style='color:black;background-color:#fd8064;text-align:right;'>0.0101</td></tr>
# </table></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Causal Model</small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Explanation : backdoor ['vaccination'] found.</small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Impact : $P( death \mid \hookrightarrow\mkern-6.5mureaction=1)$</small></div></td></tr></table>

# %%
spModele = csl.CausalModel(sp)
cslnb.showCausalImpact(spModele,on="death",doing="smallPox", values={"smallPox":1})
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="192pt" height="188pt" viewBox="0.00 0.00 192.19 188.00">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 184)">
# <title>G</title>
# <!-- vaccination -->
# <g id="node1" class="node">
# <title>vaccination</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="88.9965" cy="-162" rx="51.1914" ry="18"/>
# <text text-anchor="middle" x="88.9965" y="-158.3" font-family="Times,serif" font-size="14.00" fill="#ffffff">vaccination</text>
# </g>
# <!-- reaction -->
# <g id="node2" class="node">
# <title>reaction</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="38.9965" cy="-90" rx="38.9931" ry="18"/>
# <text text-anchor="middle" x="38.9965" y="-86.3" font-family="Times,serif" font-size="14.00" fill="#ffffff">reaction</text>
# </g>
# <!-- vaccination&#45;&gt;reaction -->
# <g id="edge1" class="edge">
# <title>vaccination-&gt;reaction</title>
# <path fill="none" stroke="#4a4a4a" d="M75.8156,-144.7726C69.8376,-136.1642 62.5509,-125.6715 55.9868,-116.2192"/>
# <path fill="none" stroke="#4a4a4a" d="M77.4584,-143.6318C71.4803,-135.0234 64.1936,-124.5307 57.6296,-115.0784"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="59.6202,-113.5619 51.0414,-107.3446 53.8706,-117.5547 59.6202,-113.5619"/>
# </g>
# <!-- smallPox -->
# <g id="node4" class="node">
# <title>smallPox</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="139.9965" cy="-90" rx="44.393" ry="18"/>
# <text text-anchor="middle" x="139.9965" y="-86.3" font-family="Times,serif" font-size="14.00" fill="#ffffff">smallPox</text>
# </g>
# <!-- vaccination&#45;&gt;smallPox -->
# <g id="edge3" class="edge">
# <title>vaccination-&gt;smallPox</title>
# <path fill="none" stroke="#4a4a4a" d="M100.7873,-143.6242C106.8849,-135.0158 114.3173,-124.523 121.0126,-115.0708"/>
# <path fill="none" stroke="#4a4a4a" d="M102.4193,-144.7803C108.5169,-136.1719 115.9493,-125.6791 122.6447,-116.2268"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="124.7867,-117.5279 127.7108,-107.3446 119.0745,-113.4818 124.7867,-117.5279"/>
# </g>
# <!-- death -->
# <g id="node3" class="node">
# <title>death</title>
# <ellipse fill="#404040" stroke="#4a4a4a" cx="88.9965" cy="-18" rx="29.795" ry="18"/>
# <text text-anchor="middle" x="88.9965" y="-14.3" font-family="Times,serif" font-size="14.00" fill="#ffffff">death</text>
# </g>
# <!-- reaction&#45;&gt;death -->
# <g id="edge2" class="edge">
# <title>reaction-&gt;death</title>
# <path fill="none" stroke="#4a4a4a" d="M50.2788,-72.0004C56.3861,-63.2059 63.9073,-52.3753 70.6351,-42.6873"/>
# <path fill="none" stroke="#4a4a4a" d="M51.9215,-73.1412C58.0288,-64.3467 65.5501,-53.5161 72.2779,-43.8281"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="74.5195,-44.983 77.3487,-34.7729 68.7699,-40.9902 74.5195,-44.983"/>
# </g>
# <!-- smallPox&#45;&gt;death -->
# <g id="edge4" class="edge">
# <title>smallPox-&gt;death</title>
# <path fill="none" stroke="#4a4a4a" d="M126.8348,-73.1488C120.5418,-64.2646 112.777,-53.3025 105.8615,-43.5395"/>
# <path fill="none" stroke="#4a4a4a" d="M128.4669,-71.9928C122.1739,-63.1086 114.4091,-52.1464 107.4936,-42.3834"/>
# <polygon fill="#4a4a4a" stroke="#4a4a4a" points="109.5137,-40.9101 100.8774,-34.7729 103.8015,-44.9563 109.5137,-40.9101"/>
# </g>
# </g>
# </svg></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style="">$$\begin{equation}P( death \mid \hookrightarrow\mkern-6.5musmallPox) = \sum_{vaccination}{P\left(death\mid smallPox,vaccination\right) \cdot P\left(vaccination\right)}\end{equation}$$</div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center" style=""><table style="border:1px solid black;">
# <tr style='border:1px solid black;color:black;background-color:#808080'><th colspan='2'><center>death</center></th></tr>
# <tr><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>0</center></th><th style='border:1px solid black;border-bottom-style: double;color:black;background-color:#BBBBBB'><center>1</center></th></tr>
# <tr><td style='color:black;background-color:#98e564;text-align:right;'>0.7970</td><td style='color:black;background-color:#e59864;text-align:right;'>0.2030</td></tr>
# </table></div></td></tr><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Causal Model</small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Explanation : backdoor ['vaccination'] found.</small></div></td><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><small>Impact : $P( death \mid \hookrightarrow\mkern-6.5musmallPox=1)$</small></div></td></tr></table>
