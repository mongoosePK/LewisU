# %% [markdown]
# ## Step 1 - import pyAgrum

# %%
import pyAgrum as gum

# %% [markdown]
# ## Step 2 - Create an empty BayesNet with a specified name

# %%
bn=gum.BayesNet('WaterSprinkler')
print(bn)
# Out:
# BN{nodes: 0, arcs: 0, domainSize: 1, dim: 0}

# %% [markdown]
# ## Step 3 - Add variables

# %%
c=bn.add(gum.LabelizedVariable('c','cloudy ?',2))
print(c)
# Out:
# 0

# %%
s, r, w = [ bn.add(name, 2) for name in "srw" ] #bn.add(name, 2) === bn.add(gum.LabelizedVariable(name, name, 2))
print (s,r,w)
print (bn)
# Out:
# 1 2 3
# BN{nodes: 4, arcs: 0, domainSize: 16, dim: 8}

# %% [markdown]
# ## Step 4 - Add Arcs

# %%
bn.addArc(c,s)

# %%
for link in [(c,r),(s,w),(r,w)]:
    bn.addArc(*link)
print(bn)
# Out:
# BN{nodes: 4, arcs: 4, domainSize: 16, dim: 18}

# %% [markdown]
# ### Import lib.notebook to get visualizations

# %%
import pyAgrum.lib.notebook as gnb
bn
# Out:
# (gum::BayesNet<double>@0x7f9eeaab0a00) BN{nodes: 4, arcs: 4, domainSize: 16, dim: 18}

# %% [markdown]
# ## Step 5 - Define CPTs for each variable

# %%
bn.cpt(c).fillWith([0.5,0.5])
# Out:
# (gum::Potential<double>@0x7f9eee018c70) <c:0> :: 0.5 /<c:1> :: 0.5

# %%
bn.cpt("c").fillWith([0.4,0.6])
# Out:
# (gum::Potential<double>@0x7f9eee018c70) <c:0> :: 0.4 /<c:1> :: 0.6

# %%
bn.cpt(s).var_names
# Out:
# ['c', 's']

# %%
bn.cpt(s)[:]=[ [0.5,0.5],[0.9,0.1]]

# %%
print(bn.cpt(s)[1])
# Out:
# [0.9 0.1]

# %%
bn.cpt(s)[0,:]=0.5 # equivalent to [0.5,0.5]
bn.cpt(s)[1,:]=[0.9,0.1]

# %%
bn.cpt(w).var_names
# Out:
# ['r', 's', 'w']

# %%
bn.cpt(w)[0,0,:] = [1, 0] # r=0,s=0
bn.cpt(w)[0,1,:] = [0.1, 0.9] # r=0,s=1
bn.cpt(w)[1,0,:] = [0.1, 0.9] # r=1,s=0
bn.cpt(w)[1,1,:] = [0.01, 0.99] # r=1,s=1

# %% [markdown]
# ### Simplest way to assign CPTs is to use dictionaries

# %%
bn.cpt(w)[{'r': 0, 's': 0}] = [1, 0]
bn.cpt(w)[{'r': 0, 's': 1}] = [0.1, 0.9]
bn.cpt(w)[{'r': 1, 's': 0}] = [0.1, 0.9]
bn.cpt(w)[{'r': 1, 's': 1}] = [0.01, 0.99]
bn.cpt(w)
# Out:
# (gum::Potential<double>@0x7f9eea3b3000) <w:0|s:0|r:0> :: 1 /<w:1|s:0|r:0> :: 0 /<w:0|s:1|r:0> :: 0.1 /<w:1|s:1|r:0> :: 0.9 /<w:0|s:0|r:1> :: 0.1 /<w:1|s:0|r:1> :: 0.9 /<w:0|s:1|r:1> :: 0.01 /<w:1|s:1|r:1> :: 0.99

# %%
bn.cpt(r)[{'c':0}]=[0.8,0.2]
bn.cpt(r)[{'c':1}]=[0.2,0.8]
bn.cpt(r)
# Out:
# (gum::Potential<double>@0x7f9eea3a82a0) <r:0|c:0> :: 0.8 /<r:1|c:0> :: 0.2 /<r:0|c:1> :: 0.2 /<r:1|c:1> :: 0.8

# %% [markdown]
# ## Formats for saving BNs

# %%
print(gum.availableBNExts())
# Out:
# bif|dsl|net|bifxml|o3prm|uai

# %% [markdown]
# ## Step 6 - Do Inference

# %% [markdown]
# ### Setup the inference engine

# %%
ie=gum.LazyPropagation(bn)

# %% [markdown]
# ### Unconditional queries (no evidence)

# %%
ie.makeInference()
print (ie.posterior(w))
# Out:
# <w:0> :: 0.33328 /<w:1> :: 0.66672

# %%
ie.posterior(w)
# Out:
# (gum::Potential<double>@0x7f9ee7e78f90) <w:0> :: 0.33328 /<w:1> :: 0.66672

# %% [markdown]
# ### Conditional queries (with evidence)

# %%
ie.setEvidence({'s':0, 'c': 0}) # hard evidence
ie.makeInference()
ie.posterior(w)
# Out:
# (gum::Potential<double>@0x7f9ee7ebfd30) <w:0> :: 0.82 /<w:1> :: 0.18

# %%
ie.setEvidence({'s': [0.5, 1], 'c': [1, 0]}) # soft evidence
ie.makeInference()
ie.posterior(w) # using gnb's feature
# Out:
# (gum::Potential<double>@0x7f9eea59fcd0) <w:0> :: 0.328 /<w:1> :: 0.672

# %% [markdown]
# ### Show distributions

# %%
gnb.showProba(ie.posterior(w))

# %%
gnb.showPosterior(bn,{'s':1,'c':0},'w')

# %% [markdown]
# ### Inference in whole Bayes Net

# %%
gnb.showInference(bn,evs={}) # no evidence

# %%
gnb.showInference(bn,evs={'s':1,'c':0}) # with hard evidence

# %%
gnb.showInference(bn,evs={'s':1,'c':[0.3,0.9]}) # with evidence - hard and soft

# %%
gnb.showInference(bn,evs={'c':[0.3,0.9]},targets={'c','w'}) # partial targets
